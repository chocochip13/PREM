# %% [markdown]
# ### Load Libraries

# %%
import pandas as pd
import numpy as np
import ppscore as pps
import seaborn as sns
import matplotlib.pyplot as plt


import warnings
warnings.filterwarnings("ignore")

# %%
AB = pd.read_csv("/Users/ks/Desktop/DDP/PREM/DATA_27APRIL2020/ABCDpps/AB.treatment.csv")
C = pd.read_csv("/Users/ks/Desktop/DDP/PREM/DATA_27APRIL2020/ABCDpps/C.treatment.csv")
D = pd.read_csv("/Users/ks/Desktop/DDP/PREM/DATA_27APRIL2020/ABCDpps/C.treatment.csv")

# %% [markdown]
# ## AB and Treatment pps

# %%
plt.figure(figsize=(16,10))
sns.heatmap(pps.matrix(AB),annot=True,fmt=".2f")
plt.title("PPS \n AB and Treatment",fontsize=25, ha='center')
plt.savefig('/Users/ks/Desktop/DDP/PREM/PREM/outputs/AB_pps')

# %%
pps.matrix(AB)
# Out:
#                             Clear airway    Obstructed  Unmaintainable  \
# Clear airway                1.000000e+00  7.257285e-01    4.776390e-01
# Obstructed                  6.535246e-01  1.000000e+00    4.957264e-06
# Unmaintainable              1.693202e-05  1.693202e-05    1.000000e+00
# Apnea                       1.163912e-05  1.163912e-05    4.247675e-01
# Distress                    1.845080e-01  1.585221e-01    7.434695e-07
# Normal.Breathing            2.748852e-01  1.765858e-01    1.182358e-01
# Head.Tilt.Chin.Lift         6.285737e-07  6.285737e-07    6.285737e-07
# Bag.valve.Mask.Ventilation  5.056734e-01  1.936743e-01    4.005678e-01
# CPAP                        1.767142e-02  3.154578e-08    3.154578e-08
# Intubation                  5.542630e-01  9.416492e-06    5.457961e-01
# 3%Saline                    1.732836e-06  1.732836e-06    1.732836e-06
# InjAminophylline            0.000000e+00  0.000000e+00    0.000000e+00
# ...

# %% [markdown]
# ## C and Treatment

# %%
plt.figure(figsize=(16,10))
sns.heatmap(pps.matrix(C),annot=True,fmt=".2f")
plt.title("PPS \n Circulation and Treatment",fontsize=25, ha='center')
plt.savefig('/Users/ks/Desktop/DDP/PREM/PREM/outputs/C_pps')

# %%
pps.matrix(C)
# Out:
#                         Brady  Normal.Circulation  Shock BP Normal  \
# Brady                1.000000            0.000014         0.000014
# Normal.Circulation   0.195113            1.000000         0.762820
# Shock BP Normal      0.000000            0.710351         1.000000
# Shock Low BP         0.000019            0.000019         0.000019
# Cardiac.Massage      0.000091            0.000091         0.000091
# Normal.Saline.Bolus  0.000002            0.000002         0.000002
# Dobutamine           0.000000            0.000000         0.000000
# Dopamine             0.000015            0.000015         0.000015
# Epinephrine          0.000027            0.000027         0.000027
# Nor-Epinephrine      0.000033            0.000033         0.000033
#
#                      Shock Low BP  Cardiac.Massage  Normal.Saline.Bolus  \
# Brady                    0.000014         0.000444         9.890579e-06
# Normal.Circulation       0.275080         0.061381         5.316008e-07
# ...

# %% [markdown]
# ## D and Treatment

# %%
plt.figure(figsize=(16,10))
sns.heatmap(pps.matrix(D),annot=True,fmt=".2f")
plt.title("PPS \n Disability and Treatment",fontsize=25, ha='center')
plt.savefig('/Users/ks/Desktop/DDP/PREM/PREM/outputs/D_pps')

# %%
pps.matrix(D)
# Out:
#                         Brady  Normal.Circulation  Shock BP Normal  \
# Brady                1.000000            0.000014         0.000014
# Normal.Circulation   0.195113            1.000000         0.762820
# Shock BP Normal      0.000000            0.710351         1.000000
# Shock Low BP         0.000019            0.000019         0.000019
# Cardiac.Massage      0.000091            0.000091         0.000091
# Normal.Saline.Bolus  0.000002            0.000002         0.000002
# Dobutamine           0.000000            0.000000         0.000000
# Dopamine             0.000015            0.000015         0.000015
# Epinephrine          0.000027            0.000027         0.000027
# Nor-Epinephrine      0.000033            0.000033         0.000033
#
#                      Shock Low BP  Cardiac.Massage  Normal.Saline.Bolus  \
# Brady                    0.000014         0.000444         9.890579e-06
# Normal.Circulation       0.275080         0.061381         5.316008e-07
# ...
